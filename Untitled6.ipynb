# %% [markdown]
# <a href="https://colab.research.google.com/github/harshjindal97/machinelearing/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
res = requests.get('https://juanroldan1989-moviequotes-v1.p.rapidapi.com/api/v1/quotes')

# %%
res.json()
# Out:
# {'message': 'Invalid API key. Go to https://docs.rapidapi.com/docs/keys for more info.'}

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints , marker = 'o')
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y , width=0.5)
plt.title('fruits price')
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]
plt.bar(x, y)
# Out:
# <BarContainer object of 2 artists>

# %%
import numpy as np

x = np.random.normal(100, 10, 250)

print(x)
# Out:
# [103.74362029 108.42402508 107.47433856 103.78097717  71.01687416
#  105.44553096 100.21385032  83.75021473 104.32237012 105.29661675
#  105.49573656  98.94124299  88.86110499  99.58099799 117.23167103
#   84.49533602  91.7131245  121.82553632  95.55614726 103.77349663
#  101.74395488  90.0103306   98.64980097  74.66228043 103.56940288
#   97.46919652  98.87602744  99.53624879  99.15878534 113.59417516
#   98.25879966 113.86733382  97.20162224  89.84435363  96.57648195
#   89.74257246 103.94051593 107.35429288  89.20719535 114.89778115
#  100.31509867  89.9374302   88.77345924  92.45690342 101.02934633
#  116.96636015  83.79477282  91.85329218  90.05417761 109.70628191
#   98.3985193   99.43205051  86.45777393 107.52489028  99.11366997
#  100.82450658  99.8190493  113.26683589 102.3066411  107.45884162
#  114.50529434 102.95699182 100.85156651 115.12451901  97.48384613
#  109.46779095 103.11474003 105.12322287 111.21845839  93.5358098
# ...

# %%
plt.hist(x)
# Out:
# (array([ 6.,  6., 24., 38., 49., 65., 32., 21.,  7.,  2.]),
#  array([ 71.01687416,  76.78144325,  82.54601234,  88.31058143,
#          94.07515052,  99.8397196 , 105.60428869, 111.36885778,
#         117.13342687, 122.89799596, 128.66256504]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15,45])

plt.pie(y)
plt.show()

# %%
plt.pie(y , labels = [1,2,3,4,5])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4c4d1239d0>,
# ...
#  [Text(0.7985950521056507, 0.7564693931365453, '1'),
#   Text(-0.5152492659437543, 0.9718632588715465, '2'),
#   Text(-1.1, 1.3471114790620887e-16, '3'),
#   Text(-0.7121248963430626, -0.8383782750097848, '4'),
#   Text(0.6173057645500666, -0.9104579029550228, '5')])

# %%
plt.pie(y , labels = [1,2,3,4,5], startangle = 40)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4c4d144280>,
# ...
#  [Text(0.1255101489525776, 1.0928161796523248, '1'),
#   Text(-1.0194054981095575, 0.41329460488131864, '2'),
#   Text(-0.8426488874308758, -0.7070663706551933, '3'),
#   Text(-0.006620152243617613, -1.099980078721552, '4'),
#   Text(1.0581147097995693, -0.300654720411593, '5')])

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.legend()
plt.show()

# %%
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
